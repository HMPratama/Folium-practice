# %% [markdown]
# ## **Modul 2: Data Analysis – Data Visualization Folium**
#
# ### **With matplotlib & seaborn**

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Library
import numpy as np
import pandas as pd

# data visual
import seaborn as sns
import matplotlib as plt

import folium

# %%
df=pd.read_csv('melb_data.csv')
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# ### **Nomor 1**
#
# - Tampilkan rumah paling mahal
# - Tandai dengan icon pin berwarna merah
# - Beri tooltip berupa "Rumah Termahal"
# - Beri popup berupa alamat/address

# %%
mean_prices = df.groupby('Address')['Price'].mean().reset_index()
sorted_mean_prices = mean_prices.sort_values(by='Price')
sorted_mean_prices
# Out:
#                 Address      Price
# 5153   202/51 Gordon St    85000.0
# 7396         30 Pyne St   131000.0
# 12624     8/6 Ridley St   145000.0
# 3578    171 Moreland Rd   145000.0
# 3546      17/17 Park St   160000.0
# ...                 ...        ...
# 2512        136 Page St  6400000.0
# 2879        15 Barry St  6500000.0
# 9719       49 Lisson Gr  7650000.0
# 9722     49 Mangarra Rd  8000000.0
# 7957        35 Bevis St  9000000.0
#
# [13378 rows x 2 columns]

# %%
df_home=df.groupby('Address')[['Price','Lattitude','Longtitude']].max().sort_values(by='Price', ascending=False)
df_home.head(20)
# Out:
#                       Price  Lattitude  Longtitude
# Address
# 35 Bevis St       9000000.0  -37.93168   145.16126
# 49 Mangarra Rd    8000000.0  -37.81790   145.06940
# 49 Lisson Gr      7650000.0  -37.82652   145.03052
# 15 Barry St       6500000.0  -37.80290   145.02670
# 136 Page St       6400000.0  -37.84908   144.95753
# 17 Albany Rd      6250000.0  -37.84860   145.02440
# 161 Church St     5800000.0  -37.91640   144.99740
# 18 Avoca St       5700000.0  -37.83770   144.98940
# 204 Page St       5600000.0  -37.85231   144.96373
# 367 Dandenong Rd  5525000.0  -37.86020   145.01300
# 17 Fairview St    5510000.0  -37.83031   145.02973
# 139 Cole St       5500000.0  -37.89544   145.00279
# 10 Myoora Rd      5500000.0  -37.84310   145.02100
# 684 Orrong Rd     5500000.0  -37.84470   145.01340
# 52 Adelaide St    5200000.0  -37.85311   145.02847
# 49 Berkeley St    5100000.0  -37.83320   145.03660
# 121 Kooyong Rd    5100000.0  -37.85249   145.02091
# ...

# %%
df[df['Address']=='35 Bevis St']
# Out:
#          Suburb      Address  Rooms Type      Price Method SellerG  \
# 12094  Mulgrave  35 Bevis St      3    h  9000000.0     PI    Hall
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 12094  29/07/2017      18.8    3170.0  ...       1.0  1.0     744.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 12094         117.0     1960.0       Monash -37.93168   145.16126
#
#                        Regionname Propertycount
# 12094  South-Eastern Metropolitan        7113.0
#
# [1 rows x 21 columns]

# %%
# Peta Melbourne
melb_map = folium.Map(location = [-37.93168, 145.16126],
                     zoom_start=10)
# buat Marker Liberty Statue
mansion = folium.Marker(location = [-37.93168, 145.16126],
                        # popup => Ketika marker di klik maka akan muncul kalimat sesuai dengan di popul
                        popup = folium.Popup('35 Bevis St, Mulgrave VIC 3170, Australia', max_width=500 ),
                        # tooltip => ketika cursor di hover ke marker
                        tooltip ="Mulgrave VIC 3170, Australia",
                        icon = folium.Icon('purple',icon="home",prefix="glyphicon",))
mansion.add_to(melb_map)
melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > ### **Insight:**
#
# >> Data mengenai rumah di kota Melbourne Mulgrave, Terdapat satu rumah yang paling mahal di daerah Mulgrave.

# %% [markdown]
# ### **Nomor 2**
#
# - Ceritanya kita sedang mencari apartment (type='u') dengan 2 kamar tidur (Bedroom2) dengan harga yg murah
# - Coba tampilkan peta kota Melbourne
# - Berikan marker berupa pin pada 5 apartment termurah
# - Berikan tooltip berupa harga rumah
# - Berikan popup berupa Suburb dan Address

# %%
df[['Bedroom2']]
# Out:
#        Bedroom2
# 0           2.0
# 1           2.0
# 2           3.0
# 3           3.0
# 4           3.0
# ...         ...
# 13575       4.0
# 13576       3.0
# 13577       3.0
# 13578       4.0
# 13579       4.0
#
# [13580 rows x 1 columns]

# %%
df_apt=df[(df['Type']=='u')&(df['Bedroom2']==2)].sort_values('Price')
df_apt[['Suburb','Address','Lattitude','Longtitude']]
df_apt.head()
# Out:
#          Suburb                Address  Rooms Type     Price Method  \
# 7303     Albion          8/6 Ridley St      1    u  145000.0     PI
# 7305     Albion         5/25 Ridley St      2    u  190000.0     SP
# 5205  Reservoir    1/164 Leamington St      1    u  216000.0      S
# 2915    Glenroy  14/854 Pascoe Vale Rd      2    u  230000.0     PI
# 5221  Reservoir         4/1067 High St      2    u  240000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 7303     Biggin  28/05/2016      13.9    3020.0  ...       1.0  1.0      36.0
# 7305    Burnham  30/07/2016      13.9    3020.0  ...       1.0  1.0       0.0
# 5205       Brad  24/09/2016      11.2    3073.0  ...       1.0  1.0       0.0
# 2915      Raine  18/03/2017      13.0    3046.0  ...       1.0  1.0    1996.0
# 5221  Stockdale  26/07/2016      11.2    3073.0  ...       1.0  1.0      82.0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
# Buat list
prc = list(df_apt.Price)
sub = list(df_apt.Suburb)
ade = list(df_apt.Address)
latid = list(df_apt.Lattitude)
lont = list(df_apt.Longtitude)

# %%
melb_map = folium.Map(location = [-37.969643, 144.3937186],
                     zoom_start=8)
for i in range(6):
    mapmarker = folium.Marker(location=[latid[i],lont[i]],
                              popup = folium.Popup(f'{sub[i]},{ade[i]}',max_width=500),
                              tooltip =  f'{prc[i],sub[i]}',
                              icon = folium.Icon(color="red",icon="home", prefix='fa'))
    mapmarker.add_to(melb_map)
melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# >### **Insight:**
#
# >> Dari data untuk apartement 2 bedroom dengan harga yang murah ada 5 apartement di daerah Melbourne.
